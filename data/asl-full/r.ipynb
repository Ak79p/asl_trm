# %%
import pandas as pd

train = pd.read_csv('train_features.csv')
test = pd.read_csv('test_features.csv')      
val = pd.read_csv('val_features.csv')

# %%
len(train), len(val), len(test)
# Out:
# (40154, 10304, 32940)

# %%
train['class_gloss'].unique()
# Out:
# array(['apple', 'impossible', 'park', ..., 'science', 'spoon', 'piano'],
#       shape=(2301,), dtype=object)

# %%
len(train)+len(test)+len(val)
# Out:
# 83398

# %%
test = pd.read_csv('test_labeled.csv')

# %%
nan_rows = test[test['feature_path'].isna()]

print("Rows with NaN in feature_path:")
print(nan_rows)

print("\nRow indices:")
print(nan_rows.index.tolist())
# Out:
# Rows with NaN in feature_path:
#                                              video_path class_gloss  class_id  \
# 2950  ASL-Citizen/videos/07428079785719932-FOREIGNER...   foreigner       770
#
#      feature_path
# 2950          NaN
#
# Row indices:
# [2950]

# %% [markdown]
# Removed corrupted video : 07428079785719932-FOREIGNER.mp4
